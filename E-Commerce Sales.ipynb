# %% [markdown]
# ### IMPORT NECESSARY LIBRARIES USING APPROPRIATE ALIASES

# %%
# Importing the pandas library with the alias 'pd'
import pandas as pd

# Importing the pyplot module from the matplotlib library with the alias 'plt'
import matplotlib.pyplot as plt

# %% [markdown]
# ### DATA EXPLORATION

# %%
# Load the dataframe
purchases_data = pd.read_csv("Ecommerce Purchases.csv")

# %%
# Check how many rows and columns are in the data
purchases_data.shape
# Out:
# (10000, 14)

# %%
# Visualize the data
purchases_data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
# Visualize first 10 rows
purchases_data.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
# Visualize last 10 rows
purchases_data.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %%
# Views the columns
columns = purchases_data.columns
columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price', 'Mail Provider'],
#       dtype='object')

# %%
# Check the data's general info
purchases_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
#  14  Mail Provider     10000 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ### DATA CLEANING

# %% [markdown]
# From the general information about our data above, we do not have missing or NAN values so there won't be need for us to handle missing values.
#
# Secondly, the data types each of the columns have been accurately matched, there won't be need for us to handle incorrect data types for each columns.
#
# The type of data cleaning that I suspect would be needed after inspecting the data would most likely be handling of outliers.

# %%
# Visualize the numerical columns to check for outliers, this would be done with the aid of a boxplot. The only column would be the purchase price column
purchases_data["Purchase Price"].plot(kind="box")

# Interestingly, the data has zero outliers and it is also a symmetrical data.
# Out:
# <Axes: >

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS TO ANSWER QUESTIONS

# %%
# Highest Purchase Prices
highest_purchase_price = purchases_data[["Purchase Price"]].max()
highest_purchase_price
# Out:
# Purchase Price    99.99
# dtype: float64

# %%
# Lowest Purchase Prices
lowest_purchase_price = purchases_data[["Purchase Price"]].min()
lowest_purchase_price
# Out:
# Purchase Price    0.0
# dtype: float64

# %%
# Average Purchase Price
average_purchase_price = purchases_data[["Purchase Price"]].mean().round(2)
average_purchase_price
# Out:
# Purchase Price    50.35
# dtype: float64

# %%
# How many french speakers were there?
french_speakers = len(purchases_data[purchases_data["Language"] == "fr"])
french_speakers
# Out:
# 1097

# %%
# Engineer job titles
engineers = purchases_data[purchases_data["Job"].str.contains("Engineer", case=False)] # Case is set to false to accommodate engineer in any case
engineers
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
# How many engineers in all
len(engineers)
# Out:
# 984

# %%
# Find the email address of the person using this IP Address- 132.207.160.22
locate_mail_using_IP = purchases_data[purchases_data["IP Address"] == "132.207.160.22"]["Email"]
locate_mail_using_IP
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %%
# How many people have masteercard as their card provider and made a purchase above 50?
mastercard_purchase_above_50 = purchases_data[(purchases_data["CC Provider"] == "Mastercard") & (purchases_data["Purchase Price"] >= 50)]
len(mastercard_purchase_above_50)
# Out:
# 405

# %%
# Find email of the person with the credit card number "4664825258997302"
locate_mail_using_credit_card_no = purchases_data[purchases_data["Credit Card"] == 4664825258997302]["Email"]
locate_mail_using_credit_card_no.head()
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %%
# How many people purchased in the morning
morning_purchases = purchases_data[purchases_data["AM or PM"] == "AM"]
len(morning_purchases)
# Out:
# 4932

# %%
# How many people purchased in the afternoon
morning_purchases = purchases_data[purchases_data["AM or PM"] == "PM"]
len(morning_purchases)
# Out:
# 5068

# %%
# Morning and Afternoon Purchases
morning_afternoon_purchases = purchases_data["AM or PM"].value_counts()
morning_afternoon_purchases
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
# Morning and Afternoon Purchases
purchases_data.groupby("AM or PM").count()
# Out:
#           Address   Lot  Browser Info  Company  Credit Card  CC Exp Date  \
# AM or PM
# AM           4932  4932          4932     4932         4932         4932
# PM           5068  5068          5068     5068         5068         5068
#
#           CC Security Code  CC Provider  Email   Job  IP Address  Language  \
# AM or PM
# AM                    4932         4932   4932  4932        4932      4932
# PM                    5068         5068   5068  5068        5068      5068
#
#           Purchase Price
# AM or PM
# AM                  4932
# PM                  5068

# %%
# How many people use credit cards that expire in 2020?
def counter():
    count = 0
    for date in purchases_data["CC Exp Date"]:
        if date.split("/")[1] == "20":
            count += 1
    print(count)
    
counter()
# Out:
# 988

# %%
# How many people use credit cards that expire in 2020?
len(purchases_data[purchases_data["CC Exp Date"].apply(lambda x:x[3:] == "20")])
# Out:
# 988

# %%
# Top 5 most popular email providers

# Create a for loop that takes in all of the mail providers from the for loop below
mail_provider = []

for email in purchases_data["Email"]:
    mail_provider.append(email.split("@")[1])

# Check the list
print(mail_provider)
# Out:
# ['yahoo.com', 'reed.com', 'morales-harrison.com', 'olson-robinson.info', 'gmail.com', 'gmail.com', 'yahoo.com', 'parks.info', 'rasmussen.com', 'hunt-huerta.com', 'hotmail.com', 'coleman.com', 'hotmail.com', 'yahoo.com', 'yahoo.com', 'yahoo.com', 'wilson.com', 'hall.com', 'yahoo.com', 'gmail.com', 'smith.info', 'hotmail.com', 'gmail.com', 'gardner-meadows.com', 'yahoo.com', 'mooney.com', 'gmail.com', 'hotmail.com', 'yahoo.com', 'yahoo.com', 'hotmail.com', 'hotmail.com', 'atkinson.com', 'yahoo.com', 'carey-davis.com', 'mcdowell.com', 'walsh.com', 'frederick.info', 'boyd-english.org', 'wells-carlson.info', 'dickerson.com', 'yahoo.com', 'gmail.com', 'martinez-thomas.com', 'yahoo.com', 'chambers.com', 'gmail.com', 'glenn.org', 'allen.com', 'gmail.com', 'obrien.org', 'cook-castillo.com', 'hotmail.com', 'yahoo.com', 'hotmail.com', 'yahoo.com', 'lawrence-warren.biz', 'morris.com', 'howe.com', 'walton.org', 'jones.biz', 'gmail.com', 'simmons-gutierrez.org', 'yahoo.com', 'gardner-anderson.com'
# ...

# %%
# Feature engineer a new column to take the mail providers
purchases_data["Mail Provider"] = mail_provider

# %%
purchases_data.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
# Top 5 email provider used
purchases_data["Mail Provider"].value_counts(sort=True).head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Mail Provider, dtype: int64

# %%
mail_providers = purchases_data.groupby("Mail Provider").size().reset_index(name="Count")

# %%
mail_providers.sort_values("Count", ascending=False)
# Out:
#            Mail Provider  Count
# 1397         hotmail.com   1638
# 3384           yahoo.com   1616
# 1053           gmail.com   1605
# 2868           smith.com     42
# 3306        williams.com     37
# ...                  ...    ...
# 1249  hart-schwartz.info      1
# 1250      hart-scott.com      1
# 1251     hart-weaver.com      1
# 1252      hart-young.com      1
# 3415  zuniga-jackson.com      1
#
# [3416 rows x 2 columns]

# %%
# Visualize the top 5 email providers
purchases_data["Email"].apply(lambda x:x.split("@")[1]).value_counts().head().plot(kind="bar", rot=30)
# Out:
# <Axes: >
